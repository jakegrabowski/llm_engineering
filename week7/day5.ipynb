# %% [markdown]
# # Week 7 Days 5
#
# Fine-tune an open-source model to Predict Product Prices
#
# Please see this notebook in Google Colab:
#
# https://colab.research.google.com/drive/16e8aY_BlHjzzcR-2dCyDMCPdOQ8XeN1e?usp=sharing

# %% [markdown]
# completed week 7 day 5 on Google Colab:
# [Copy of NEW Week 7 Day 5 - Testing our Fine-tuned model](https://colab.research.google.com/drive/18zZPXP6FCFXMZnAXKJFZaA29a8dPNdG_)
