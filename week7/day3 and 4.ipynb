# %% [markdown]
# # Week 7 Days 3 and 4
#
# Fine-tune an open-source model to Predict Product Prices
#
# Please see this notebook in Google Colab:
#
# https://colab.research.google.com/drive/1fBTm_jzrFGr88PDOFTQF7JIlQ1JW15BG?usp=sharing

# %% [markdown]
# lite version (appliance price prediction only) completed on 12/23/2025
#
#
# google colab:
# [Copy of NEW Week 7 Day 3: TRAINING.ipynb](https://colab.research.google.com/drive/1iMj6rJWglEMPrcdwEHXvILqDBWHwOVZ2)
#
# base on data [sjmoses/items_prompts_lite](https://huggingface.co/datasets/sjmoses/items_prompts_lite)
#
# saved to hugging face: [sjmoses/price-2025-12-22_18.55.50-lite](https://huggingface.co/sjmoses/price-2025-12-22_18.55.50-lite)
